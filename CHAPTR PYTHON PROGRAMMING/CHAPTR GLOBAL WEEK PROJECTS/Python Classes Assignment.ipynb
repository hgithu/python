# %%
#part one

class Node():
	a = 10
    
n = Node.a  
v = n


print(n)
print(v)
print(str(n)==str(v))
# Out:
# 10
# 10
# True

# %%
#Part Two 
import datetime

class Students:
    
    def __init__(self,fname, lname, birthdate):
        self.fname = fname
        self.lname = lname
        self.birthdate = birthdate
        
    def fullname(self):
        return (self.fname+" "+self.lname)
    
    
    def age(self):
        today = datetime.date.today()
        age = today.year - self.birthdate.year
        
        if today < datetime.date(today.year, self.birthdate.month, self.birthdate.day):
            age -= 1

        return age

student = Students(
"Humphrey",
    "Nduati",
    datetime.date(1988, 8, 31)
    
)

print(student.fname, student.lname)
print(student.age())
# Out:
# Humphrey Nduati
# 33

# %%
#part 3
import math
class circle():
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*(self.radius**2)
    
r=float(input("Enter radius of circle: "))
obj=circle(r)
print("Area of circle:",round(obj.area(),0))


class triangle_area:
    def __init__(self, a, b, c):
        self.a = float(a)
        self.b = float(b)
        self.c = float(c)
        self.area = 0

    def calculate_area(self):
        s = (self.a + self.b + self.c) / 2
        self.area = float((s * (s - self.a) * (s - self.b) * (s - self.c))) ** 0.5

    def get_area(self):
        return self.area     

a, b, c = input("a = "), input("b = "), input("c = ")

t = triangle_area(a, b, c)
t.calculate_area()
print("area : {}".format(t.get_area()))


class Rectangle_Area:
    def area_Rect(self, x, y):
        return x*y

print("Enter Length and Width of Rectangle: ", end="")
l = float(input())
w = float(input())


cobj = Rectangle_Area()
a = cobj.area_Rect(l, w)
if a < 0:
    raise ValueError
    
    
else: 
    print("DON'T USE NEGATIVE UNITS")

print("\nArea = {:.2f}".format(a))
# Out:
# Enter radius of circle: 3
# Area of circle: 28.27
# a = 3
# b = 3
# c = 3
# area : 3.897114317029974
# Enter Length and Width of Rectangle: 3
# 3
# DON'T USE NEGATIVE UNITS
#
# Area = 9.00

# %% [markdown]
# ### part 4#
# import math
#
# class Complex():
#
#     def __init__(self, real, imaginary):
#         self.real = real
#         self.imaginary = imaginary
#
#     def __add__(self, no):
#         real = self.real + no.real
#         imaginary = self.imaginary + no.imaginary
#         return Complex(real,imaginary)
#
#     def __sub__(self, no):
#         real = self.real - no.real
#         imaginary = self.imaginary - no.imaginary
#         return Complex(real,imaginary)
#
#     def __mul__(self, no):
#         real = self.real * no.real - self.imaginary * no.imaginary
#         imaginary = self.real * no.imaginary + self.imaginary * no.real
#         return Complex(real,imaginary)
#
#     def __truediv__(self, no):
#         x = float(no.real ** 2 + no.imaginary ** 2)
#         y = self * Complex(no.real, -no.imaginary)
#         real = y.real / x
#         imaginary = y.imaginary / x
#         return Complex(real, imaginary)
#
#     def mod(self):
#         real = math.sqrt(self.real ** 2 + self.imaginary ** 2)
#         return Complex(real, 0)
#
#     def __str__(self):
#         if self.imaginary == 0:
#             result = "%.2f+0.00i" % (self.real)
#         elif self.real == 0:
#             if self.imaginary >= 0:
#                 result = "0.00+%.2fi" % (self.imaginary)
#             else:
#                 result = "0.00-%.2fi" % (abs(self.imaginary))
#         elif self.imaginary > 0:
#             result = "%.2f+%.2fi" % (self.real, self.imaginary)
#         else:
#             result = "%.2f-%.2fi" % (self.real, abs(self.imaginary))
#         return result
#
#     def assert_funcion(c_string,d_string, res_list):
#         c = map(float, c_string.split())
#         d = map(float, d_string.split())
#         x = Complex(*c)
#         y = Complex(*d)
#         result = list(map(str, [x+y, x-y, x*y, x/y, x.mod(), y.mod()]) )
#         c_string =["2 1"]
#         d_string = ["5 6"]
#         result_list = ['7.00+7.00i', '-3.00-5.00i', '4.00+17.00i', '16.00-7.00i', '2.24+0.00i', '7.81+0.00i']
#
#         print(*map(str, assert_funcion(c_string, d_string, result_list)), sep='\n')
#
#         for c_ ,d_ , result_ in zip(c_strings,  d_strings , result_lists):
#             assert_funcion(c_, d_, result_)
#
#         try :
#
#             assert res_list == result
#         except AssertionError:
#             error_msg ="ASSERTION ERROR :\n Error with result for :"
#         print(error_msg + "\n c_string = {} , d_string = {}" .format(c_string ,d_string))
#
#         return result
